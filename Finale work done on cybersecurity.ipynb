# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pk

# %%
x = pd.read_excel("Datasets\output2019_2020_2021.xlsx")
df = pd.DataFrame(x)
df
# Out:
#       SL                    State/UT   2019   2020   2021  \
# 0    1.0              Andhra Pradesh   1886   1899   1875
# 1    2.0           Arunachal Pradesh      8     30     47
# 2    3.0                       Assam   2231   3530   4846
# 3    4.0                       Bihar   1050   1512   1413
# 4    5.0                Chhattisgarh    175    297    352
# 5    6.0                         Goa     15     40     36
# 6    7.0                     Gujarat    784   1283   1536
# 7    8.0                     Haryana    564    656    622
# 8    9.0            Himachal Pradesh     76     98     70
# 9   10.0                   Jharkhand   1095   1204    953
# 10  11.0                   Karnataka  12020  10741   8136
# 11  12.0                      Kerala    307    426    626
# 12  13.0              Madhya Pradesh    602    699    589
# 13  14.0                 Maharashtra   4967   5496   5562
# 14  15.0                     Manipur      4     79     67
# ...

# %%
df = df.drop(['SL'], axis = 1)
df.head()
# Out:
#             State/UT  2019  2020  2021  \
# 0     Andhra Pradesh  1886  1899  1875
# 1  Arunachal Pradesh     8    30    47
# 2              Assam  2231  3530  4846
# 3              Bihar  1050  1512  1413
# 4       Chhattisgarh   175   297   352
#
#    Mid-Year Projected Population (in Lakhs)  \
# 0                                     528.5
# 1                                      15.4
# 2                                     351.6
# 3                                    1237.0
# 4                                     296.1
#
#    Rate of Total Cyber Crimes (2021)  Chargesheeting Rate (2021)  \
# 0                                3.5                        31.8
# 1                                3.1                        60.0
# 2                               13.8                        15.9
# 3                                1.1                        50.2
# 4                                1.2                        83.0
#
# ...

# %%
temp=df.select_dtypes(exclude=["object"])
temp.corr()
# Out:
#                                               2019      2020      2021  \
# 2019                                      1.000000  0.998996  0.995346
# 2020                                      0.998996  1.000000  0.998549
# 2021                                      0.995346  0.998549  1.000000
# Mid-Year Projected Population (in Lakhs)  0.978325  0.984543  0.988397
# Rate of Total Cyber Crimes (2021)         0.968816  0.975880  0.983118
# Chargesheeting Rate (2021)                0.926927  0.935356  0.943320
# Total 2002(IT Act and IPC)                0.905254  0.914142  0.923294
# Total 2003(IT Act and IPC)                0.896029  0.902630  0.910489
# Total 2004(IT Act and IPC)                0.898880  0.908056  0.916832
# Total 2005(IT Act and IPC)                0.922167  0.928686  0.934313
# Total 2006(IT Act and IPC)                0.916243  0.924678  0.934632
# Total 2007(IT Act and IPC)                0.932961  0.941200  0.950637
# ...

# %%
df = df.drop(27, axis = 0)

# %%
df = df.drop([36, 37], axis = 0)

# %%
df.set_index(np.arange(1, 36, 1), inplace=True)
df
# Out:
#                       State/UT   2019   2020  2021  \
# 1               Andhra Pradesh   1886   1899  1875
# 2            Arunachal Pradesh      8     30    47
# 3                        Assam   2231   3530  4846
# 4                        Bihar   1050   1512  1413
# 5                 Chhattisgarh    175    297   352
# 6                          Goa     15     40    36
# 7                      Gujarat    784   1283  1536
# 8                      Haryana    564    656   622
# 9             Himachal Pradesh     76     98    70
# 10                   Jharkhand   1095   1204   953
# 11                   Karnataka  12020  10741  8136
# 12                      Kerala    307    426   626
# 13              Madhya Pradesh    602    699   589
# 14                 Maharashtra   4967   5496  5562
# 15                     Manipur      4     79    67
# 16                   Meghalaya     89    142   107
# 17                     Mizoram      8     13    30
# ...

# %%
start_col = 2019
end_col = "Total 2018(IT Act and IPC)"
subset_df = df.loc[:, start_col:end_col]

plt.figure(figsize = (10, 8))
sns.heatmap(subset_df, cmap = "inferno")
plt.xlabel("Years")
plt.ylabel("Attacks in numbers")
plt.title("heatmap")
plt.show()

# %% [markdown]
# ScatterPlot for Number of cyber attacks from 2002 to 2018

# %%
start_col = "Total 2002(IT Act and IPC)"
end_col = "Total 2018(IT Act and IPC)"

subset_df = df.loc[:, start_col:end_col]

plt.figure(figsize = (9, 9))
for column in subset_df.columns:
    plt.scatter(subset_df[column], subset_df.index, label = column)
    
plt.xlabel("Totality")
plt.ylabel("Number of attacks")
plt.title("Scatterplot for Total attacks vs Increasing years")
plt.legend()

plt.show()

# %%
columns_to_group_by = ['State/UT','Total 2002(IT Act and IPC)', 'Total 2003(IT Act and IPC)', 'Total 2004(IT Act and IPC)', 'Total 2005(IT Act and IPC)', 'Total 2006(IT Act and IPC)', 'Total 2007(IT Act and IPC)', 'Total 2008(IT Act and IPC)', 'Total 2009(IT Act and IPC)', 'Total 2010(IT Act and IPC)', 'Total 2011(IT Act and IPC)', 'Total 2012(IT Act and IPC)', 'Total 2013(IT Act and IPC)', 'Total 2014(IT Act and IPC)', 'Total 2015(IT Act and IPC)', 'Total 2016(IT Act and IPC)', 'Total 2017(IT Act and IPC)', 'Total 2018(IT Act and IPC)', 2019, 2020, 2021]

# Create a subset DataFrame with the specified range of columns
subset_df = df[columns_to_group_by]

# Group the data by the columns in the subset and calculate the sum of 'CyberAttacks' for each group
grouped = subset_df.groupby('State/UT')["Total 2002(IT Act and IPC)"].sum()

result_df = pd.DataFrame(grouped).reset_index()

plt.plot(grouped)
plt.xlabel("States")
plt.ylabel("Number of attacks")
plt.title("States VS Attacks in 2002")
plt.xticks(rotation = 90)
plt.show()

# %%
result_df
# Out:
#                       State/UT  Total 2002(IT Act and IPC)
# 0                  A&N Islands                          15
# 1               Andhra Pradesh                         261
# 2            Arunachal Pradesh                           0
# 3                        Assam                           2
# 4                        Bihar                           0
# 5                   Chandigarh                           2
# 6                 Chhattisgarh                           0
# 7   D&N Haveli and Daman & Diu                           0
# 8                        Delhi                           7
# 9                          Goa                           8
# 10                     Gujarat                         250
# 11                     Haryana                           2
# 12            Himachal Pradesh                          99
# 13             Jammu & Kashmir                           7
# 14                   Jharkhand                           1
# ...

# %%
columns_to_group_by = ['State/UT', 'Total 2002(IT Act and IPC)', 'Total 2003(IT Act and IPC)', 'Total 2004(IT Act and IPC)', 'Total 2005(IT Act and IPC)', 'Total 2006(IT Act and IPC)', 'Total 2007(IT Act and IPC)', 'Total 2008(IT Act and IPC)', 'Total 2009(IT Act and IPC)', 'Total 2010(IT Act and IPC)', 'Total 2011(IT Act and IPC)', 'Total 2012(IT Act and IPC)', 'Total 2013(IT Act and IPC)', 'Total 2014(IT Act and IPC)', 'Total 2015(IT Act and IPC)', 'Total 2016(IT Act and IPC)', 'Total 2017(IT Act and IPC)', 'Total 2018(IT Act and IPC)', 2019, 2020, 2021]

# Create a subset DataFrame with the specified range of columns
subset_df = df[columns_to_group_by]
grouped1 = subset_df.groupby("State/UT")["Total 2003(IT Act and IPC)"].sum()

result_df1 = pd.DataFrame(grouped1).reset_index()

plt.plot(grouped1)
plt.xlabel("States")
plt.ylabel("Number of attacks")
plt.title("States VS Attacks in 2003")
plt.xticks(rotation = 90)
plt.show()

# %%
result_df1
# Out:
#                       State/UT  Total 2003(IT Act and IPC)
# 0                  A&N Islands                          16
# 1               Andhra Pradesh                         221
# 2            Arunachal Pradesh                           0
# 3                        Assam                           0
# 4                        Bihar                           0
# 5                   Chandigarh                           1
# 6                 Chhattisgarh                           0
# 7   D&N Haveli and Daman & Diu                           0
# 8                        Delhi                           0
# 9                          Goa                           2
# 10                     Gujarat                          29
# 11                     Haryana                           1
# 12            Himachal Pradesh                          87
# 13             Jammu & Kashmir                           5
# 14                   Jharkhand                           0
# ...

# %%
df.head(6)
# Out:
#             State/UT  2019  2020  2021  \
# 1     Andhra Pradesh  1886  1899  1875
# 2  Arunachal Pradesh     8    30    47
# 3              Assam  2231  3530  4846
# 4              Bihar  1050  1512  1413
# 5       Chhattisgarh   175   297   352
# 6                Goa    15    40    36
#
#    Mid-Year Projected Population (in Lakhs)  \
# 1                                     528.5
# 2                                      15.4
# 3                                     351.6
# 4                                    1237.0
# 5                                     296.1
# 6                                      15.6
#
#    Rate of Total Cyber Crimes (2021)  Chargesheeting Rate (2021)  \
# 1                                3.5                        31.8
# 2                                3.1                        60.0
# 3                               13.8                        15.9
# 4                                1.1                        50.2
# ...

# %%
df = df.drop(['Mid-Year Projected Population (in Lakhs)'], axis = 1)
df = df.drop(['Rate of Total Cyber Crimes (2021)'], axis = 1)
df = df.drop(['Chargesheeting Rate (2021)'], axis = 1)
df.head()
# Out:
#             State/UT  2019  2020  2021  Total 2002(IT Act and IPC)  \
# 1     Andhra Pradesh  1886  1899  1875                         261
# 2  Arunachal Pradesh     8    30    47                           0
# 3              Assam  2231  3530  4846                           2
# 4              Bihar  1050  1512  1413                           0
# 5       Chhattisgarh   175   297   352                           0
#
#    Total 2003(IT Act and IPC)  Total 2004(IT Act and IPC)  \
# 1                         221                         101
# 2                           0                           0
# 3                           0                           0
# 4                           0                           0
# 5                           0                           0
#
#    Total 2005(IT Act and IPC)  Total 2006(IT Act and IPC)  \
# 1                           0                           0
# 2                           1                           0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
def weight(input, output):
  mean_x = np.mean(input)
  mean_y = np.mean(output)
  theta_1 = (np.sum((input - mean_x) * (output - mean_y))) / (np.sum((input - mean_x)**2))
  
  theta_0 = mean_y - theta_1 * mean_x
  return [theta_0, theta_1]

# %%
df.head()
# Out:
#             State/UT  2019  2020  2021  Total 2002(IT Act and IPC)  \
# 1     Andhra Pradesh  1886  1899  1875                         261
# 2  Arunachal Pradesh     8    30    47                           0
# 3              Assam  2231  3530  4846                           2
# 4              Bihar  1050  1512  1413                           0
# 5       Chhattisgarh   175   297   352                           0
#
#    Total 2003(IT Act and IPC)  Total 2004(IT Act and IPC)  \
# 1                         221                         101
# 2                           0                           0
# 3                           0                           0
# 4                           0                           0
# 5                           0                           0
#
#    Total 2005(IT Act and IPC)  Total 2006(IT Act and IPC)  \
# 1                           0                           0
# 2                           1                           0
# ...

# %%
a = df.drop(2021,axis=1)
b = df[2021]
display(a.head())
display(b.head())
# Out:
#             State/UT  2019  2020  Total 2002(IT Act and IPC)  \
# 1     Andhra Pradesh  1886  1899                         261
# 2  Arunachal Pradesh     8    30                           0
# 3              Assam  2231  3530                           2
# 4              Bihar  1050  1512                           0
# 5       Chhattisgarh   175   297                           0
#
#    Total 2003(IT Act and IPC)  Total 2004(IT Act and IPC)  \
# 1                         221                         101
# 2                           0                           0
# 3                           0                           0
# 4                           0                           0
# 5                           0                           0
#
#    Total 2005(IT Act and IPC)  Total 2006(IT Act and IPC)  \
# 1                           0                           0
# 2                           1                           0
# 3                           0                           1
# ...

# %%
a
# Out:
#                       State/UT   2019   2020  Total 2002(IT Act and IPC)  \
# 1               Andhra Pradesh   1886   1899                         261
# 2            Arunachal Pradesh      8     30                           0
# 3                        Assam   2231   3530                           2
# 4                        Bihar   1050   1512                           0
# 5                 Chhattisgarh    175    297                           0
# 6                          Goa     15     40                           8
# 7                      Gujarat    784   1283                         250
# 8                      Haryana    564    656                           2
# 9             Himachal Pradesh     76     98                          99
# 10                   Jharkhand   1095   1204                           1
# 11                   Karnataka  12020  10741                           0
# 12                      Kerala    307    426                          15
# ...

# %%
a = a.set_index('State/UT')

# %%
from sqlalchemy import Null

a.index.name = None

# %%
a
# Out:
#                              2019   2020  Total 2002(IT Act and IPC)  \
# Andhra Pradesh               1886   1899                         261
# Arunachal Pradesh               8     30                           0
# Assam                        2231   3530                           2
# Bihar                        1050   1512                           0
# Chhattisgarh                  175    297                           0
# Goa                            15     40                           8
# Gujarat                       784   1283                         250
# Haryana                       564    656                           2
# Himachal Pradesh               76     98                          99
# Jharkhand                    1095   1204                           1
# Karnataka                   12020  10741                           0
# Kerala                        307    426                          15
# Madhya Pradesh                602    699                           4
# ...

# %%
a = a.astype("float64")

# %%
a.columns = a.columns.astype(str)

# %% [markdown]
# My reference, to predict 2021 from data range 2002-2020

# %%
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size = 0.2, random_state = 42)
 
# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared (R2) Score:", r2)
# Out:
# Mean Squared Error: 992399.5688305332
# R-squared (R2) Score: 0.9071861367138209

# %%
with open("model.pkl","wb") as file:
    pk.dump(model,file)

# %%
plt.scatter(a['2019'], b)
plt.show()

# %% [markdown]
# Let's see how GPR looks like for the same training data

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, Matern

# %%
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size = 0.2, random_state = 42)

# Define the RBF kernel with a white noise term
length_scale = 1.0
nu = 1.5  # Adjust the nu parameter as needed
kernel = 1.0 * RBF(length_scale = length_scale) + 1.0 * WhiteKernel()

# Create and train the Gaussian Process Regression model
model = GaussianProcessRegressor(kernel = kernel, n_restarts_optimizer = 10, random_state = 42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred, y_std = model.predict(X_test, return_std = True)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared (R2) Score:", r2)

# Plot the results (optional)
plt.figure(figsize = (10, 6))
plt.scatter(X_train.index, y_train, label = 'Training Data')
plt.plot(X_test.index, y_pred, color = 'r', label = 'Predicted Mean')
plt.fill_between(X_test.index, y_pred - 1.96 * y_std, y_pred + 1.96 * y_std, color = 'b', alpha = 0.2, label = '95% Confidence Interval')
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.ylabel('Attacks in numbers')
plt.title('Gaussian Process Regression with RBF kernel')
plt.legend()
plt.show()
# Out:
# d:\Python\Lib\site-packages\sklearn\gaussian_process\kernels.py:429: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\gaussian_process\kernels.py:429: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Mean Squared Error: 13842600.961968938
# R-squared (R2) Score: -0.2946249812697297
