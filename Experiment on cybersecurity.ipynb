# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_excel("C:\\Users\\post2\\OneDrive\\Documents\\Random datasets\\Cyber crime in India since 2003\\All years datasets\\output2003.xlsx")
df = pd.DataFrame(x)

df
# Out:
#    Evaluation Only. Created with Aspose.PDF. Copyright 2002-2023 Aspose Pty Ltd.  \
# 0                                         TABLE-18.1
# 1   Incidence Of Cases Registered Under Cyber Crim...
# 2                           and Percentage Variation
# 3                                               SL.No
# 4                                                 NaN
# 5                                                   1
# 6                                                   1
# 7                                                   2
# 8                                                   3
# 9                                                   4
# 10                                                  5
# 11                                                  6
# 12                                                  7
# 13                                                  8
# 14                                                  9
# 15                                                 10
# ...

# %%
df=df.drop(["Evaluation Only. Created with Aspose.PDF. Copyright 2002-2023 Aspose Pty Ltd."],axis=1)
df
# Out:
#             Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                  NaN         NaN        NaN        NaN         NaN
# 1                  NaN         NaN        NaN        NaN         NaN
# 2                  NaN         NaN        NaN        NaN         NaN
# 3             State/UT         NaN    IT ACT         NaN         NaN
# 4                  NaN      2002.0       2003  Variation      2002.0
# 5                    2         3.0          4          5         6.0
# 6       ANDHRA PRADESH         8.0          3     -62.50       253.0
# 7    ARUNACHAL PRADESH         0.0          0          -         0.0
# 8                ASSAM         2.0          0    -100.00         0.0
# 9                BIHAR         0.0          0          -         0.0
# 10        CHHATTISGARH         0.0          0          -         0.0
# 11                 GOA         4.0          2     -50.00         4.0
# 12             GUJARAT         1.0         14       1300       249.0
# ...

# %%
df=df.iloc[6:44,:]
df
# Out:
#             Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 6       ANDHRA PRADESH         8.0          3     -62.50       253.0
# 7    ARUNACHAL PRADESH         0.0          0          -         0.0
# 8                ASSAM         2.0          0    -100.00         0.0
# 9                BIHAR         0.0          0          -         0.0
# 10        CHHATTISGARH         0.0          0          -         0.0
# 11                 GOA         4.0          2     -50.00         4.0
# 12             GUJARAT         1.0         14       1300       249.0
# 13             HARYANA         2.0          0    -100.00         0.0
# 14    HIMACHAL PRADESH         0.0          0          -        99.0
# 15    JAMMU & KASHMIR          1.0          0   -100.00          0.0
# 16           JHARKHAND         0.0          0          -         0.0
# 17           KARNATAKA        15.0          7     -53.33         0.0
# 18              KERALA         3.0          1     -66.67         1.0
# ...

# %%
col_ind=["State/UT","2002","2003","Variation","2002","2003","Variation"]
df=df.set_axis(col_ind,axis=1)
df=df.set_axis(np.arange(1,df.shape[0]+1,1),axis=0)
df
# Out:
#               State/UT  2002 2003 Variation   2002 2003 Variation
# 1       ANDHRA PRADESH   8.0    3    -62.50  253.0  218    -13.83
# 2    ARUNACHAL PRADESH   0.0    0         -    0.0    0         -
# 3                ASSAM   2.0    0   -100.00    0.0    0         -
# 4                BIHAR   0.0    0         -    0.0    0         -
# 5         CHHATTISGARH   0.0    0         -    0.0    0         -
# 6                  GOA   4.0    2    -50.00    4.0    0   -100.00
# 7              GUJARAT   1.0   14      1300  249.0   15    -93.98
# 8              HARYANA   2.0    0   -100.00    0.0    1         -
# 9     HIMACHAL PRADESH   0.0    0         -   99.0   87    -12.12
# 10    JAMMU & KASHMIR    1.0    0  -100.00     0.0    0        -
# 11           JHARKHAND   0.0    0         -    0.0    0         -
# 12           KARNATAKA  15.0    7    -53.33    0.0    1         -
# 13              KERALA   3.0    1    -66.67    1.0    0   -100.00
# ...

# %%
df.to_csv("Attacks in 2003.csv")
